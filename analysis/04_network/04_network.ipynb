# %% [markdown]
# ## Setting

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = (Path.cwd().parent).parent        

NETWORK_DIR = ROOT / "04_network"
DATA_DIR    = ROOT / "data"/ "04_network"

sys.path.insert(0, str(NETWORK_DIR))

from PCMCI import load_pcmci_dataframe, run_pcmci_gpdc, results_to_long_df

FIG_DIR = ROOT / "figures" / "04_network"
RES_DIR = ROOT / "results" / "04_network"

FIG_DIR.mkdir(parents=True, exist_ok=True)
RES_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Action Binding

# %%
# Cell 2  Action binding
csv_path = DATA_DIR / "action_binding_for_network.csv"
dataframe, regions, data = load_pcmci_dataframe(csv_path)

results = run_pcmci_gpdc(
    dataframe=dataframe,
    regions=regions,
    label="Action binding",
    tau_max=3,
    pc_alpha=0.05,
    alpha_level=0.05,
    save_fig_path=FIG_DIR / "action_binding.png",
    show_fig=True,
)

df_long = results_to_long_df(results, regions, tau_min=1, tau_max=3)
df_long.to_csv(RES_DIR / "action_binding.csv", index=False)
df_long.head(10)
# Out:
# [Action binding] tau_max=3
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = gp_dc
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable PreSMAL has 2 link(s):
#         (PreSMAL -1): max_pval = 0.00000, |min_val| =  0.721
#         (PreSMAL -2): max_pval = 0.00400, |min_val| =  0.463
#
#     Variable PreSMAR has 2 link(s):
#         (PreSMAR -1): max_pval = 0.00000, |min_val| =  0.764
#         (PreSMAR -2): max_pval = 0.00000, |min_val| =  0.544
#
#     Variable SMAR has 3 link(s):
#         (SMAR -1): max_pval = 0.00000, |min_val| =  0.725
#         (PreSMAR -1): max_pval = 0.00400, |min_val| =  0.468
#         (SMAR -2): max_pval = 0.01600, |min_val| =  0.424
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
# ...

# %% [markdown]
# ## Outcome Binding

# %%
# Cell 3  Outcome binding
csv_path = DATA_DIR / "outcome_binding_for_network.csv"
dataframe, regions, data = load_pcmci_dataframe(csv_path)

results = run_pcmci_gpdc(
    dataframe=dataframe,
    regions=regions,
    label="Outcome binding",
    tau_max=3,
    pc_alpha=0.1,
    alpha_level=0.1,
    save_fig_path=FIG_DIR / "outcome_binding.png",
    show_fig=True,
)

df_long = results_to_long_df(results, regions, tau_min=1, tau_max=3)
df_long.to_csv(RES_DIR / "outcome_binding.csv", index=False)
df_long.head(10)
# Out:
# [Outcome binding] tau_max=3
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = gp_dc
# tau_min = 1
# tau_max = 3
# pc_alpha = [0.1]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable MTGR has 3 link(s):
#         (MTGR -1): max_pval = 0.00000, |min_val| =  0.720
#         (MTGR -2): max_pval = 0.02600, |min_val| =  0.312
#         (PostcentralL -3): max_pval = 0.09800, |min_val| =  0.256
#
#     Variable PostcentralL has 2 link(s):
#         (PostcentralL -1): max_pval = 0.00000, |min_val| =  0.645
#         (PostcentralL -2): max_pval = 0.00000, |min_val| =  0.453
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 3
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable MTGR has 4 link(s):
#         (MTGR -1): pval = 0.00000 | val =  0.778
# ...

# %% [markdown]
# ## 75% and 50% (without outcome)

# %%
# Cell 4  75% and 50% (without outcome)
csv_path = DATA_DIR / "75_50_without_outcome_for_network.csv"
dataframe, regions, data = load_pcmci_dataframe(csv_path)

results = run_pcmci_gpdc(
    dataframe=dataframe,
    regions=regions,
    label="75% and 50% (without outcome)",
    tau_max=5,
    pc_alpha=0.05,
    alpha_level=0.05,
    save_fig_path=FIG_DIR / "75_50_without_outcome.png",
    show_fig=True,
)

df_long = results_to_long_df(results, regions, tau_min=1, tau_max=5)
df_long.to_csv(RES_DIR / "75_50_without_outcome.csv", index=False)
df_long.head(10)
# Out:
# [75% and 50% (without outcome)] tau_max=5
#
# ##
# ## Step 1: PC1 algorithm for selecting lagged conditions
# ##
#
# Parameters:
# independence test = gp_dc
# tau_min = 1
# tau_max = 5
# pc_alpha = [0.05]
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Resulting lagged parent (super)sets:
#
#     Variable AGR has 1 link(s):
#         (AGR -1): max_pval = 0.00000, |min_val| =  0.649
#
#     Variable DLPFCR has 1 link(s):
#         (DLPFCR -1): max_pval = 0.00000, |min_val| =  0.671
#
#     Variable PrecuneusR has 3 link(s):
#         (PrecuneusR -1): max_pval = 0.00000, |min_val| =  0.642
#         (PrecuneusR -2): max_pval = 0.01400, |min_val| =  0.352
#         (DLPFCR -1): max_pval = 0.03600, |min_val| =  0.332
#
# ##
# ## Step 2: MCI algorithm
# ##
#
# Parameters:
#
# independence test = gp_dc
# tau_min = 1
# tau_max = 5
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable AGR has 3 link(s):
# ...
