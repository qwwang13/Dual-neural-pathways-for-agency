# %% [markdown]
# ## Input

# %%
from pathlib import Path
import sys
import pandas as pd

ROOT = (Path.cwd().parent).parent   
LMM_DIR = ROOT / "05_LMM"  

sys.path.insert(0, str(LMM_DIR))

from ITPC import export_angles_itpc


DATA_DIR = ROOT / "data" / "05_LMM" 
OUT_DIR  = ROOT / "data" / "05_LMM"  / "plot_data_for_itpc"

FREQS = list(range(1, 30))

# %% [markdown]
# ## Action binding

# %%
# Cell 3  Action binding
action_jobs = [
    ("PreSMAR_action_ba.csv", (0.19, 0.25), [19]),
    ("PreSMAL_action_ba.csv", (0.20, 0.29), [19]),
    ("SMAR_action_ba.csv",    (0.18, 0.26), [19]),
]

action_records = []
for fname, tw, excl in action_jobs:
    csv_path = DATA_DIR / fname
    angles_csv, itpc_csv, angles_df, itpc_mean_df = export_angles_itpc(
        csv_path=csv_path,
        time_window=tw,
        out_dir=OUT_DIR,
        freqs=FREQS,
        exclude_subjects=excl,
    )
    action_records.append(
         {"file": fname, "time_window": tw, "angles_csv": str(angles_csv.relative_to(ROOT)), "itpc_csv": str(itpc_csv.relative_to(ROOT))}
    )

pd.DataFrame(action_records)
# Out:
#                     file   time_window  \
# 0  PreSMAR_action_ba.csv  (0.19, 0.25)
# 1  PreSMAL_action_ba.csv   (0.2, 0.29)
# 2     SMAR_action_ba.csv  (0.18, 0.26)
#
#                                           angles_csv  \
# 0  data\05_LMM\plot_data_for_itpc\PreSMAR_action_...
# 1  data\05_LMM\plot_data_for_itpc\PreSMAL_action_...
# 2  data\05_LMM\plot_data_for_itpc\SMAR_action_ba_...
#
#                                             itpc_csv
# 0  data\05_LMM\plot_data_for_itpc\PreSMAR_action_...
# 1  data\05_LMM\plot_data_for_itpc\PreSMAL_action_...
# 2  data\05_LMM\plot_data_for_itpc\SMAR_action_ba_...

# %% [markdown]
# ## Outcome binding

# %%
outcome_jobs = [
    ("PostcentralL_outcome_bs.csv", (0.20, 0.30), []),
    ("MTGR_outcome_bs.csv",         (0.77, 0.85), []),
]

outcome_records = []
for fname, tw, excl in outcome_jobs:
    csv_path = DATA_DIR / fname
    angles_csv, itpc_csv, angles_df, itpc_mean_df = export_angles_itpc(
        csv_path=csv_path,
        time_window=tw,
        out_dir=OUT_DIR,
        freqs=FREQS,
        exclude_subjects=excl,
    )
    outcome_records.append(
        {"file": fname, "time_window": tw, "angles_csv": str(angles_csv.relative_to(ROOT)), "itpc_csv": str(itpc_csv.relative_to(ROOT))}
    )

pd.DataFrame(outcome_records)
# Out:
#                           file   time_window  \
# 0  PostcentralL_outcome_bs.csv    (0.2, 0.3)
# 1          MTGR_outcome_bs.csv  (0.77, 0.85)
#
#                                           angles_csv  \
# 0  data\05_LMM\plot_data_for_itpc\PostcentralL_ou...
# 1  data\05_LMM\plot_data_for_itpc\MTGR_outcome_bs...
#
#                                             itpc_csv
# 0  data\05_LMM\plot_data_for_itpc\PostcentralL_ou...
# 1  data\05_LMM\plot_data_for_itpc\MTGR_outcome_bs...

# %% [markdown]
# ## 75% and 50% without outcome

# %%
no_outcome_jobs = [
    ("AGR_75_50_ba.csv",        (0.42, 0.56), []),
    ("DLPFCR_75_50_ba.csv",     (0.54, 0.62), []),
    ("PrecuneusR_75_50_ba.csv", (0.24, 0.36), []),
]

no_outcome_records = []
for fname, tw, excl in no_outcome_jobs:
    csv_path = DATA_DIR / fname
    angles_csv, itpc_csv, angles_df, itpc_mean_df = export_angles_itpc(
        csv_path=csv_path,
        time_window=tw,
        out_dir=OUT_DIR,
        freqs=FREQS,
        exclude_subjects=excl,
    )
    no_outcome_records.append(
         {"file": fname, "time_window": tw, "angles_csv": str(angles_csv.relative_to(ROOT)), "itpc_csv": str(itpc_csv.relative_to(ROOT))}
    )

pd.DataFrame(no_outcome_records)
# Out:
#                       file   time_window  \
# 0         AGR_75_50_ba.csv  (0.42, 0.56)
# 1      DLPFCR_75_50_ba.csv  (0.54, 0.62)
# 2  PrecuneusR_75_50_ba.csv  (0.24, 0.36)
#
#                                           angles_csv  \
# 0  data\05_LMM\plot_data_for_itpc\AGR_75_50_ba_an...
# 1  data\05_LMM\plot_data_for_itpc\DLPFCR_75_50_ba...
# 2  data\05_LMM\plot_data_for_itpc\PrecuneusR_75_5...
#
#                                             itpc_csv
# 0  data\05_LMM\plot_data_for_itpc\AGR_75_50_ba_it...
# 1  data\05_LMM\plot_data_for_itpc\DLPFCR_75_50_ba...
# 2  data\05_LMM\plot_data_for_itpc\PrecuneusR_75_5...

# %% [markdown]
# ## 50 with and without outcome

# %%
mix_jobs = [
    ("STGR_50_ba.csv", (0.60, 0.64), []),
]

mix_records = []
for fname, tw, excl in mix_jobs:
    csv_path = DATA_DIR / fname
    angles_csv, itpc_csv, angles_df, itpc_mean_df = export_angles_itpc(
        csv_path=csv_path,
        time_window=tw,
        out_dir=OUT_DIR,
        freqs=FREQS,
        exclude_subjects=excl,
    )
    mix_records.append(
         {"file": fname, "time_window": tw, "angles_csv": str(angles_csv.relative_to(ROOT)), "itpc_csv": str(itpc_csv.relative_to(ROOT))}
    )

pd.DataFrame(mix_records)
# Out:
#              file  time_window  \
# 0  STGR_50_ba.csv  (0.6, 0.64)
#
#                                           angles_csv  \
# 0  data\05_LMM\plot_data_for_itpc\STGR_50_ba_angl...
#
#                                             itpc_csv
# 0  data\05_LMM\plot_data_for_itpc\STGR_50_ba_itpc...
